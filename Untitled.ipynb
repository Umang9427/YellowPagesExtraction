# %%
import requests
from bs4 import BeautifulSoup
import json
import lxml
data=[]
obj={}

# %%
from selenium import webdriver


chromedrive_path = "chromedriver_win32\chromedriver.exe" 
driver = webdriver.Chrome(chromedrive_path)
# Out:
# C:\Users\TARANG BHALANI\AppData\Local\Temp\ipykernel_32856\1099892238.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedrive_path)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

main_list = []

def extract(url):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36'}
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.content, 'html.parser')
    return soup.find_all('div', class_ = 'v-card')

def transform(articles):
    for item in articles:
        name = item.find('a', class_ = 'business-name').text
        print(name)
        try:
            website = item.find('a', class_ = 'track-visit-website')['href']
        except:
            website = ''

        business = {
            'name': name,
            'website': website
        }
        main_list.append(business)
    return

def load():
    df = pd.DataFrame(main_list)
    df.to_csv('coffeeshopsglasgow.csv', index=False)

for x in range(1,7):
    print(f'Getting page {x}')
    articles = extract(f'https://www.yellowpages.com/search?search_terms=architect&geo_location_terms=Ontario%2C%20CA&page={x}')
    transform(articles)

load()
print('Saved to CSV')
# Out:
# Getting page 1
# Brian Bloom Architect
# HMC Architects
# Tjs Architects
# Genesis Architectural Products
# Innovative Architectural Solutions
# Architectural Testing
# HMC Architects
# Cano Architecture Concrete Repair
# Abgb Architects
# Phil May Landscape Architects
# The Financial Architects
# Pete Volbeda Architect
# GO Architects Inc.
# Williams Architects Inc
# Studio 3 Architects
# DC Architects
# Volbeda Pete Architects Owner
# Brian H Lee Architect
# Architectural Painting
# Architectural Theme Solutions
# WLC Architects Inc
# Amor Architectural Corporation
# Paul Wheeler Architect
# Maureen McPROUD Wheeler Architect
# Wheeler & Wheeler Architects
# Sautter Architecture
# Financial Architects
# Biben & Bosley Architecture
# Rugby Architectural Bldg Prod
# Eric Kough Architects Inc
# Getting page 2
# Curtis J Dahle Architect
# Cummins Architecture & Design
# Williams Architects
# Elite Sheet Metal & Architectural Inc
# The Financial Architects
# ...

# %%
import re
import requests
from urllib.parse import urlsplit
from collections import deque
from bs4 import BeautifulSoup
import pandas as pd

original_url = input("Enter the website url: ") 

unscraped = deque([original_url])  

scraped = set()  

emails = set()  

while len(unscraped):
    url = unscraped.popleft()  
    scraped.add(url)

    parts = urlsplit(url)
        
    base_url = "{0.scheme}://{0.netloc}".format(parts)
    if '/' in parts.path:
      path = url[:url.rfind('/')+1]
    else:
      path = url

    print("Crawling URL %s" % url)
    try:
        response = requests.get(url)
    except (requests.exceptions.MissingSchema, requests.exceptions.ConnectionError):
        continue

    new_emails = set(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.com", response.text, re.I))
    emails.update(new_emails) 

    soup = BeautifulSoup(response.text, 'lxml')

    for anchor in soup.find_all("a"):
      if "href" in anchor.attrs:
        link = anchor.attrs["href"]
      else:
        link = ''

        if link.startswith('/'):
            link = base_url + link
        
        elif not link.startswith('http'):
            link = path + link

        if not link.endswith(".gz"):
          if not link in unscraped and not link in scraped:
              unscraped.append(link)

df = pd.DataFrame(emails, columns=["Email"])
df.to_csv('email.csv', index=False)
# Out:
# Enter the website url: http://goarchitectsinc.com
# Crawling URL http://goarchitectsinc.com
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In [47], line 56
#      53               unscraped.append(link)
#      55 df = pd.DataFrame(emails, columns=["Email"])
# ---> 56 df.to_csv('email.csv', index=False)
#
# File c:\users\tarang bhalani\desktop\marketing and scraping\python\myenv\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...
